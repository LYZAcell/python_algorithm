# %% [markdown]
# <a href="https://colab.research.google.com/github/LYZAcell/python_algorithm/blob/main/BDA(%ED%8C%90%EB%8B%A4%EC%8A%A4)/%EC%88%98%EC%97%85_1229_%EC%9D%B4%EA%B0%80%EC%98%8141.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 공지

# %% [markdown]
# 1. 방학 일정 : slack 콜라보, 여러 부트캠프 참여 요망
# 2. 10기 모집 예정: 트랙 세분화 예정
#   - 데이터 리터러시 영역
#   - 프로그래밍
#   - 데이터분석 트랙
#   - 데이터 사이언스 트랙
#   - AI 트랙
# 3. 임원진 모집 중

# %% [markdown]
# # 수업
# ## 데이터 병합 (Merge)

# %% [markdown]
# 조건에 따라 아래의 함수를 선택하여 쓰면 된다
# - 다만 잘못된 방법으로 병합할 시 문제 발생
# - 병합은 필수적인 요소. 머신러닝 분야는 필수로 병합과정이 들어가고 분석에서도 필수적인 분야
# - 원하는 데이터셋을 구성하기 위해서는 필수적이다.
#
# ## 병합 함수들
# - concat
# - merge
# - join

# %% [markdown]
# ## 코드

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})
df2 = pd.DataFrame({'A':[4,5],'B':[6,7]})
df3 = pd.DataFrame({'A':[11,12],'B':[6,7],'C':[100,200]})

# %% [markdown]
# ### Concat:  덩어리 + 덩어리 ( 데이터 프레임 + 데이터프레임)
# 데이터프레임
#
# +
#
# 데이터프레임 형식으로 붙는다
#
# - 축 지정이 필요하다. axis = 0 (행) or 1 (열 기준)
# - concat 후 N/A값과 index에 유의 해야한다 ( 기존의 인덱스를 유지하여 0,1,2, 0-1을 유지할 수도 )

# %%
display(df1, df2, df3)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
#    A  B
# 0  4  6
# 1  5  7
#     A  B    C
# 0  11  6  100
# 1  12  7  200

# %%
# df1 + df2
pd. concat([df1, df2], axis = 0) # 행기준 _ 인덱싱이 0 1 2 - 0, 1이라 concat이후에는 꼭 indexing확인 필요
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# 0  4  6
# 1  5  7

# %%
pd.concat([df1, df2], axis = 1) # 이렇게 잘못설계해 붙이면 N/A가 발생해 곤란해질 수 있다
# Out:
#    A  B    A    B
# 0  1  4  4.0  6.0
# 1  2  5  5.0  7.0
# 2  3  6  NaN  NaN

# %%
# 세개 합병
display(pd.concat([df1, df2, df3], axis = 0))
# Out:
#     A  B      C
# 0   1  4    NaN
# 1   2  5    NaN
# 2   3  6    NaN
# 0   4  6    NaN
# 1   5  7    NaN
# 0  11  6  100.0
# 1  12  7  200.0

# %%
display(pd.concat([df1, df2, df3], axis = 1)) # NAN값에 유의해야한다.
# Out:
#    A  B    A    B     A    B      C
# 0  1  4  4.0  6.0  11.0  6.0  100.0
# 1  2  5  5.0  7.0  12.0  7.0  200.0
# 2  3  6  NaN  NaN   NaN  NaN    NaN

# %%
## 인덱스 재정렬 _ ignore_index = True 해주기
display(pd.concat([df1, df2, df3], axis = 1, ignore_index = True))
# Out:
#    0  1    2    3     4    5      6
# 0  1  4  4.0  6.0  11.0  6.0  100.0
# 1  2  5  5.0  7.0  12.0  7.0  200.0
# 2  3  6  NaN  NaN   NaN  NaN    NaN

# %% [markdown]
# ### Merge

# %% [markdown]
# - Concat과의 차이점: join이 가능하다
#   - sql, pk, 공통의 컬럼으로 데이터를 병합할 수 있다
# - 공통의 컬럼 기준이 필요할 것
# - 그 컬럼의 기준을 통해서 데이터를 병합하기
# - **처음 작성한 데이터프레임이 기준이 된다** (= 첫번재가 된다)
#   - ignore_index 가 필요없다

# %% [markdown]
# - left - 병합한 첫번째 프레임
# - right : 병합한 두번째 데이터 프레임
# - how: 병합 방식 옵션, default = inner, 기타 left, right, outer이 있다
# - on: 공통 컬럼 지정하기. (지정하지 않을 시 알아서 공통열을 사용한다) _ 어지간히 병합할 때 지정해주는 게 좋다
# - left_on : 공통열을 지정하는데 두 테이블의 컬럼명이 다르지만 공통인 경우에는 직접 지정해서 컬럼 세팅이 필요하다
# - right_on : 비슷하지만 오른쪽으로 붙여주는 역할
# - left_index:  인덱스로 병합하기
# - right_index: 마찬가지

# %%
df1 = pd.DataFrame({'이름':['홍길동','박길동','이길동','최길동', '오길동'],
                    '분반':['프로그래밍','빅데이터분석','통계','인공지능','데이터리터러시']})
df2 = pd.DataFrame({'이름':['홍길동','박길동','이길동','최길동', '오길동'],
                    '점수':[100, 80,90,75,85]})

# %%
pd.merge(df1, df2, how = 'inner')
# Out:
#     이름       분반   점수
# 0  홍길동    프로그래밍  100
# 1  박길동   빅데이터분석   80
# 2  이길동       통계   90
# 3  최길동     인공지능   75
# 4  오길동  데이터리터러시   85

# %%
pd.merge(df1, df2, how = 'left')
# Out:
#     이름       분반   점수
# 0  홍길동    프로그래밍  100
# 1  박길동   빅데이터분석   80
# 2  이길동       통계   90
# 3  최길동     인공지능   75
# 4  오길동  데이터리터러시   85

# %%
pd.merge(df1, df2, how = 'outer')
# Out:
#     이름       분반   점수
# 0  박길동   빅데이터분석   80
# 1  오길동  데이터리터러시   85
# 2  이길동       통계   90
# 3  최길동     인공지능   75
# 4  홍길동    프로그래밍  100

# %%
pd.merge(df1, df2, how = 'right')
# Out:
#     이름       분반   점수
# 0  홍길동    프로그래밍  100
# 1  박길동   빅데이터분석   80
# 2  이길동       통계   90
# 3  최길동     인공지능   75
# 4  오길동  데이터리터러시   85

# %% [markdown]
# ## Join

# %% [markdown]
# - 알아두면 좋지만 index 등의 제한으로 대부분의 경우 merge가 선호됨
# - df간에 중복데이터가 있다면 : 같은 데이터 중복이 생긴다
#   - 공통 사용 컬럼 pk에 중복값을 ㅘㄱ인해야함
#   - df1에 홍길동, 프로그래밍  100 , df2에 홍길동, 데분, 80 있으면 merge하면 표 개수가 늘어난다

# %%
# 추후 df3.merge 문법 예제 드라이브 업로드

# %%
# df 세개 정도 한번에 합치고 싶다면?

# %% [markdown]
# ### numpy 데이터 병합

# %% [markdown]
# - 메모리 효율이 넘파이가 더 좋아 자주 사용된다
# - array배열로 1차원, 2차원 간의 연산, 병합 진행 시 주로 사용
# - np.concatenate, np.hstack, np.vstack

# %%
import numpy as np

# %%
# concatenate 연산필기
# column_stack
